# %%
import pandas as pd
zipCodeData = pd.read_csv("zipcode_demog.csv")
zipCodeData
# Out:
#            STATION  ZIPCODE  NETTRAFFIC  POPULATION  MALEPOP  FEMALEPOP  \
# 0   34 ST-PENN STA    10001     1359919       27384       48         52
# 1  34 ST-HERALD SQ    10001     1235562       27384       48         52
# 2   TIMES SQ-42 ST    10036     1202284       32315       56         44
# 3   59 ST COLUMBUS    10023      821797       66985       45         55
# 4  GRD CNTRL-42 ST    10017      714067       17680       45         55
# 5            59 ST    10022      703646       31924       45         55
# 6    FLUSHING-MAIN    11354      640164       54878       47         53
# 7      CHAMBERS ST    10007      630919        6988       57         43
# 8            86 ST    10024      614139       59283       46         54
# 9  42 ST-PORT AUTH    10036      595416       24711       56         44
#
#    INCOMEPERHH  NUMOFBUSINESS
# 0        85168           7296
# 1        85168           7296
# 2        83812           6085
# 3       115080           2280
# 4       106795           4892
# 5       123693           6309
# 6        43660           3586
# 7       234958           1492
# 8       118594           1971
# 9        83812           6085

# %%
zipCodeData.dropna(how = 'any', inplace= True)
pd.to_numeric(zipCodeData.POPULATION)
pd.to_numeric(zipCodeData.NETTRAFFIC)

type(zipCodeData.NETTRAFFIC)
# Out:
# pandas.core.series.Series

# %%
import seaborn as sns
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="POPULATION", data=zipCodeData)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation=50)
Population_chart2 =Population_chart.twinx()
zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="r")

# %%
ax = df.plot(x="date", y="column1", legend=False)
ax2 = ax.twinx()
df.plot(x="date", y="column2", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()

# %%
zipCodeData
# Out:
#            STATION  ZIPCODE    NETTRAFFIC POPULATION  MALEPOP  FEMALEPOP  \
# 0   34 ST-PENN STA  10001.0  1,359,919.00  27,384.00    48.26      51.74
# 1  34 ST-HERALD SQ  10001.0  1,235,562.00  27,384.00    48.26      51.74
# 2   TIMES SQ-42 ST  10036.0  1,202,284.00  32,315.00    55.79      44.21
# 3   59 ST COLUMBUS  10023.0    821,797.00  66,985.00    45.21      54.79
# 4  GRD CNTRL-42 ST  10017.0    714,067.00  17,680.00    45.16      54.84
# 5            59 ST  10022.0    703,646.00  31,924.00    45.38      54.62
# 6    FLUSHING-MAIN  11354.0    640,164.00  54,878.00    46.75      53.25
# 7      CHAMBERS ST  10007.0    630,919.00   6,988.00    56.64      43.36
# 8            86 ST  10024.0    614,139.00  59,283.00    46.28      53.72
# 9  42 ST-PORT AUTH  10036.0    595,416.00  24,711.00    55.79      44.21
#
#   INCOMEPERHH NUMOFBUSINESS
# 0   85,168.00      7,296.00
# 1   85,168.00      7,296.00
# 2   83,812.00      6,085.00
# 3  115,080.00      2,280.00
# 4  106,795.00      4,892.00
# 5  123,693.00      6,309.00
# 6   43,660.00      3,586.00
# 7  234,958.00      1,492.00
# 8  118,594.00      1,971.00
# 9   83,812.00      6,085.00

# %%
import pandas as pd
zipCodeData = pd.read_csv("zipcode_demog.csv")
zipCodeData
# Out:
#            STATION  ZIPCODE  NETTRAFFIC  POPULATION  MALEPOP  FEMALEPOP  \
# 0   34 ST-PENN STA    10001     5121294       27384       48         52
# 1  34 ST-HERALD SQ    10001     4858363       27384       48         52
# 2   TIMES SQ-42 ST    10036     4661201       32315       56         44
# 3   59 ST COLUMBUS    10023     3093385       66985       45         55
# 4  GRD CNTRL-42 ST    10017     2970536       17680       45         55
# 5            59 ST    10022     2685340       31924       45         55
# 6    FLUSHING-MAIN    11354     2516369       54878       47         53
# 7      CHAMBERS ST    10007     2438149        6988       57         43
# 8   47-50 STS ROCK    10020     2354520           0        0          0
# 9  42 ST-PORT AUTH    10036     2327873       24711       56         44
#
#    INCOMEPERHH  NUMOFBUSINESS
# 0        85168           7296
# 1        85168           7296
# 2        83812           6085
# 3       115080           2280
# ...

# %%
zipCodeData.dropna(how = 'any', inplace= True)
pd.to_numeric(zipCodeData.POPULATION)
pd.to_numeric(zipCodeData.NETTRAFFIC)

type(zipCodeData.NETTRAFFIC)
# Out:
# pandas.core.series.Series

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="POPULATION", data=zipCodeData, palette=("colorblind"),label = None)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Population_chart.set_xlabel("")
Population_chart.set_ylabel('POPULATION',size = 20)
Population_chart2 =Population_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('polulation_station.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="NUMOFBUSINESS", data=zipCodeData, palette=("colorblind"),label = None)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Population_chart.set_xlabel("")
Population_chart.set_ylabel('BUSINESS',size = 20)
Population_chart2 =Population_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('number_bussiness_station.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="FEMALEPOP", data=zipCodeData, palette=("colorblind"),label = None)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Population_chart.set_xlabel("")
Population_chart.set_ylabel('FEMALE_PERCENT',size = 20)
Population_chart2 =Population_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('female_station.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)

# %%
Population_chart = sns.barplot(x="STATION", y= 'FEMALEPOP', data=zipCodeData)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation=50)
Population_chart2 =Population_chart.twinx()
zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="r")

# %%
ax = df.plot(x="date", y="column1", legend=False)
ax2 = ax.twinx()
df.plot(x="date", y="column2", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()

# %%
zipCodeData

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Population_chart = sns.barplot(x="STATION", y="INCOMEPERHH", data=zipCodeData, palette=("colorblind"),label = None)
Population_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Population_chart.set_xlabel("")
Population_chart.set_ylabel('INCOME',size = 20)
Population_chart2 =Population_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="NETTRAFFIC", ax=Population_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('income_station.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)

# %%
import pandas as pd
zipCodeData = pd.read_csv("zipcode_demog.csv")
zipCodeData
# Out:
#            STATION  ZIPCODE  ENTRIES  NUMOFBUSINESS
# 0  34 ST-HERALD SQ    10001  1026496           7296
# 1   TIMES SQ-42 ST    10036   927166           6085
# 2   34 ST-PENN STA    10001   747193           7296
# 3   47-50 STS ROCK    10020   705707            764
# 4   59 ST COLUMBUS    10023   680502           2280
# 5  GRD CNTRL-42 ST    10017   621743           4892
# 6      CHAMBERS ST    10007   608533           1492
# 7            59 ST    10022   582138           6309
# 8            23 ST    10010   532428           3052
# 9  42 ST-BRYANT PK    10018   467758           6578

# %%
import seaborn as sns
from pylab import savefig
sns.set(style="whitegrid")
Business_chart = sns.barplot(x="STATION", y="NUMOFBUSINESS", data=zipCodeData, palette=("colorblind"),label = None)
Business_chart.set_xticklabels(zipCodeData.STATION,rotation= 90)
Business_chart.set_xlabel("")
Business_chart.set_ylabel('NUMOFBUSINESS',size = 20)
Business_chart2 =Business_chart.twinx()
fig = zipCodeData.plot(x="STATION", y="ENTRIES", ax=Business_chart2, legend=True, color="black",grid=False, linewidth = 5)

#%config InlineBackend.figure_format = 'jpeg'
figure = fig.get_figure()    
figure.savefig('entries_business.jpeg', dpi= 3000, bbox_inches='tight')

#sns.set_context("poster")
#sns.set_context("poster", font_scale= 1)
